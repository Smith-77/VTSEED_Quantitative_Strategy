# %%
import src.Backtester as btst
import src.Strategy as str
import src.StoplossType as slt
import datetime
import src.DatabaseConnector as dbc
import src.Results
import os

# %%
# Create Strategy
strategy1 = str.Strategy(max_holdings=5, days_between_rebalance=3, stoploss_type=slt.StoplossType.ABSOLUTE, trailing_days=None)

dbConn = dbc.DatabaseConnector("./persistence/databases/test_data.db")

# Create Backtester and backtest strategy
backtester = btst.Backtester()
resultsDF = backtester.backtest(strategy1, datetime.date(2022, 1, 1), datetime.date(2022, 1, 20))

# Visualize the backtest
# visualizer = vs.Visualizer(backtestID)
# visualizer.plot()
# Out:
# CURRENT DATE:  2022-01-01
# 	Rebalancing holdings...
# 2022-01-01
#
# CURRENT DATE:  2022-01-02
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-03
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-04
# 	Rebalancing holdings...
# 2022-01-04
#
# CURRENT DATE:  2022-01-05
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-06
# 	Evaluating for stoplosses...
# 		Selling AAP due to stoploss
#
# CURRENT DATE:  2022-01-07
# 	Rebalancing holdings...
# 2022-01-07
# AAP
#
# CURRENT DATE:  2022-01-08
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-09
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-10
# 	Rebalancing holdings...
# 2022-01-10
# AAP
#
# CURRENT DATE:  2022-01-11
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-12
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-13
# 	Rebalancing holdings...
# 2022-01-13
# AAP
#
# CURRENT DATE:  2022-01-14
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-15
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-16
# 	Rebalancing holdings...
# 2022-01-16
# AAP
#
# CURRENT DATE:  2022-01-17
# 	Evaluating for stoplosses...
# 		Selling ACN due to stoploss
#
# CURRENT DATE:  2022-01-18
# 	Evaluating for stoplosses...
#
# CURRENT DATE:  2022-01-19
# 	Rebalancing holdings...
# 2022-01-19
# AAP
# ACN
#           Date Ticker Exchange Date_First_Bought Repeat Multiplier  Price  \
# 0   2022-01-01    AES     NYSE        2022-01-01  False          1  43.64
# 1   2022-01-01    ALK     NYSE        2022-01-01  False          1  97.84
# 2   2022-01-01    ALB     NYSE        2022-01-01  False          1  91.99
# 3   2022-01-01   ABBV     NYSE        2022-01-01  False          1  35.70
# 4   2022-01-01    AAP     NYSE        2022-01-01  False          1  73.76
# ..         ...    ...      ...               ...    ...        ...    ...
# 90  2022-01-19    ALL     NYSE        2022-01-04   True          1  76.74
# 91  2022-01-19    ALK     NYSE        2022-01-01   True          1  97.70
# 92  2022-01-19   ALLE     NYSE        2022-01-04   True          1  91.28
# 93  2022-01-19    AAP     NYSE        2022-01-01   True          1  73.70
# 94  2022-01-19    ACN     NYSE        2022-01-04   True          1  79.35
#
#      Cash
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 90  False
# 91  False
# 92  False
# 93   True
# 94   True
#
# [95 rows x 8 columns]
#           Date   Price
# 0   2022-01-01  342.93
# 1   2022-01-02  342.93
# 2   2022-01-03  342.93
# 3   2022-01-04  416.89
# 4   2022-01-05  416.89
# 5   2022-01-06  416.89
# 6   2022-01-07  417.53
# 7   2022-01-08  417.53
# 8   2022-01-09  417.53
# 9   2022-01-10  419.14
# 10  2022-01-11  419.14
# 11  2022-01-12  419.14
# 12  2022-01-13  420.46
# 13  2022-01-14  420.46
# 14  2022-01-15  420.46
# 15  2022-01-16  419.84
# 16  2022-01-17  419.84
# 17  2022-01-18  419.84
# 18  2022-01-19  418.77

# %%
resultsDF.plot()
rawDF = resultsDF._rawDF
rawDF.head(500)
# Out:
#           Date Ticker Exchange Date_First_Bought Repeat Multiplier  Price  \
# 0   2022-01-01    AES     NYSE        2022-01-01  False          1  43.64
# 1   2022-01-01    ALK     NYSE        2022-01-01  False          1  97.84
# 2   2022-01-01    ALB     NYSE        2022-01-01  False          1  91.99
# 3   2022-01-01   ABBV     NYSE        2022-01-01  False          1  35.70
# 4   2022-01-01    AAP     NYSE        2022-01-01  False          1  73.76
# ..         ...    ...      ...               ...    ...        ...    ...
# 90  2022-01-19    ALL     NYSE        2022-01-04   True          1  76.74
# 91  2022-01-19    ALK     NYSE        2022-01-01   True          1  97.70
# 92  2022-01-19   ALLE     NYSE        2022-01-04   True          1  91.28
# 93  2022-01-19    AAP     NYSE        2022-01-01   True          1  73.70
# 94  2022-01-19    ACN     NYSE        2022-01-04   True          1  79.35
#
#      Cash
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 90  False
# 91  False
# 92  False
# 93   True
# 94   True
#
# [95 rows x 8 columns]
