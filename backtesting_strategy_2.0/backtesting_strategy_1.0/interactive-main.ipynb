# %%
import src.Backtester as btst
import src.Strategy as str
import src.StoplossStrategy as sls
import src.StoplossType as slt
import datetime
import src.DatabaseConnector as dbc
import src.Results
import os

# %%
# Create Strategy
stoplossStrategy = sls.StoplossStrategy(type="absolute", maxDrop=.0075, trailing_days=None)
strategy1 = str.Strategy(max_holdings=5, days_between_rebalance=3, stoplossStrategy=stoplossStrategy)

# Create Backtester and backtest strategy
backtester = btst.Backtester("./persistence/databases/test_data.db")
resultsDF = backtester.backtest(strategy1, datetime.date(2022, 1, 1), datetime.date(2022, 1, 20))

# Visualize the backtest
# visualizer = vs.Visualizer(backtestID)
# visualizer.plot()
# Out:
# CURRENT DATE:  2022-01-01
# 	Rebalancing holdings...
#
# CURRENT DATE:  2022-01-02
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-03
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-04
# 	Rebalancing holdings...
#
# CURRENT DATE:  2022-01-05
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
# 		Selling ALL due to stoploss
# 		Selling ALLE due to stoploss
#
# CURRENT DATE:  2022-01-06
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
# 		Selling AAP due to stoploss
#
# CURRENT DATE:  2022-01-07
# 	Rebalancing holdings...
# ALL
# ALLE
# AAP
#
# CURRENT DATE:  2022-01-08
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-09
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-10
# 	Rebalancing holdings...
# ALL
# ALLE
# AAP
#
# CURRENT DATE:  2022-01-11
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
# 		Selling ALK due to stoploss
# 		Selling ACN due to stoploss
#
# CURRENT DATE:  2022-01-12
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-13
# 	Rebalancing holdings...
# ALL
# ALLE
# AAP
# ALK
# ACN
#
# CURRENT DATE:  2022-01-14
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-15
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-16
# 	Rebalancing holdings...
# ALL
# ALLE
# AAP
# ALK
# ACN
#
# CURRENT DATE:  2022-01-17
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-18
# 	Evaluating for stoplosses...
# StoplossType.ABSOLUTE
#
# CURRENT DATE:  2022-01-19
# 	Rebalancing holdings...
# ALL
# ALLE
# AAP
# ALK
# ACN
#           Date Ticker Exchange Date_First_Bought Repeat Multiplier  Price  \
# 0   2022-01-01    AES     NYSE        2022-01-01  False          1  43.64
# 1   2022-01-01    ALK     NYSE        2022-01-01  False          1  97.84
# 2   2022-01-01    ALB     NYSE        2022-01-01  False          1  91.99
# 3   2022-01-01   ABBV     NYSE        2022-01-01  False          1  35.70
# 4   2022-01-01    AAP     NYSE        2022-01-01  False          1  73.76
# ..         ...    ...      ...               ...    ...        ...    ...
# 90  2022-01-19    ALL     NYSE        2022-01-04  False          1  74.62
# 91  2022-01-19   ALLE     NYSE        2022-01-04  False          1  91.40
# 92  2022-01-19    AAP     NYSE        2022-01-01   True          1  73.70
# 93  2022-01-19    ALK     NYSE        2022-01-01   True          1  98.84
# 94  2022-01-19    ACN     NYSE        2022-01-04   True          1  80.22
#
#      Cash
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 90   True
# 91   True
# 92   True
# 93   True
# 94   True
#
# [95 rows x 8 columns]
#           Date   Price
# 0   2022-01-01  342.93
# 1   2022-01-02  342.93
# 2   2022-01-03  342.93
# 3   2022-01-04  416.89
# 4   2022-01-05  416.89
# 5   2022-01-06  416.89
# 6   2022-01-07  417.26
# 7   2022-01-08  417.26
# 8   2022-01-09  417.26
# 9   2022-01-10  418.78
# 10  2022-01-11  418.78
# 11  2022-01-12  418.78
# 12  2022-01-13  418.78
# 13  2022-01-14  418.78
# 14  2022-01-15  418.78
# 15  2022-01-16  418.78
# 16  2022-01-17  418.78
# 17  2022-01-18  418.78
# 18  2022-01-19  418.78

# %%
resultsDF.plot()
rawDF = resultsDF._rawDF
rawDF.head(500)
# Out:
#           Date Ticker Exchange Date_First_Bought Repeat Multiplier  Price  \
# 0   2022-01-01    AES     NYSE        2022-01-01  False          1  43.64
# 1   2022-01-01    ALK     NYSE        2022-01-01  False          1  97.84
# 2   2022-01-01    ALB     NYSE        2022-01-01  False          1  91.99
# 3   2022-01-01   ABBV     NYSE        2022-01-01  False          1  35.70
# 4   2022-01-01    AAP     NYSE        2022-01-01  False          1  73.76
# ..         ...    ...      ...               ...    ...        ...    ...
# 90  2022-01-19    ALL     NYSE        2022-01-04  False          1  74.62
# 91  2022-01-19   ALLE     NYSE        2022-01-04  False          1  91.40
# 92  2022-01-19    AAP     NYSE        2022-01-01   True          1  73.70
# 93  2022-01-19    ALK     NYSE        2022-01-01   True          1  98.84
# 94  2022-01-19    ACN     NYSE        2022-01-04   True          1  80.22
#
#      Cash
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 90   True
# 91   True
# 92   True
# 93   True
# 94   True
#
# [95 rows x 8 columns]
